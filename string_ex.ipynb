# %% [markdown]
# 1. find the length of a given string without using the len() function

# %%
s= input("enter a string")
count = 0
for i in s:
    count+=1
print('length of a string is:',count)
# Out:
# length of a string is: 4

# %% [markdown]
# 2.extract username for a given email.
# eg if the email is annu1234@gmail.com then the username should be annu1234

# %%
s = input("enter a email")
pos = s.index('@')
print('Username:',s[0:pos])
# Out:
# username annuverma

# %% [markdown]
# 3. count the frequency of a particular charcater in a provided string.
# eg . 'hello how are you ' is the string ,the frequency of h in this string is 2

# %%
s = input("enter a string")
s.count('hello')
# Out:
# 3

# %%
s= input('enter the email')
term = input('what would like to search for')
count = 0
for i in s:
    if i==term:
        count += 1
print('frequency',count)
# Out:
# 7

# %% [markdown]
# write a program which can remove a particular charcter from a string

# %%
s= input('enter the email')
term = input('what would like to search for')
result =''
for i in s:
    if i != term:
        result= result +i
print(result)
# Out:
# au

# %% [markdown]
# write a program that can check whether a given string is palindrome or not

# %%
s = input("enter a string ")
rev = s[::-1
if s==rev:
    print("string is palindrome")
else:
    print("not a palindrome")
# Out:
# string is palindrome

# %%
s = input("enter a string")
flag = True 
for i in range(0,len(s)//2):
    if s[i] !=s[len(s)-i-1]:flag = False
    print("not a palindrome")
    break
if flag:
    print('palindrome')
# Out:
# not a palindrome

# %% [markdown]
# write  a program to count the no of words in a string without split()

# %%
s = input("enter a string")
L=[]
temp = ''

for i in s:
    if i!= '':
        temp = temp+i
    else:
        L.append(temp)
        temp =''
L.append(temp)
print(L)
# Out:
# ['a nun nhjj njk']

# %% [markdown]
# write a python program to convert a string to title case without using the title

# %%
s = input("enter the string")
L=[]
for i in s.split():
    L.append(i[0].upper()+i[1:].lower())
print(" ".join(L))
# Out:
# FgVhhGm

# %% [markdown]
# write aprogram that can convert an integer to string

# %%
number = int(input("enter the number"))
digits = '0123456789'
result=''
while number !=0:
    result = digits[number%10]+result
    number=number//10
    
print(result)
print(type(result))
# Out:
# 345
# <class 'str'>
