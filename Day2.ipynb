# %% [markdown]
# module in python

# %%
# math
import math
print(math.factorial(5))
print(math.floor(6.8))
print(math.sqrt(196))
# Out:
# 120
# 6
# 14.0

# %%
# keyword
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# random
import random
print(random.randint(1,100))
# Out:
# 87

# %%
# datetime
import datetime
print(datetime.datetime.now())
# Out:
# 2026-08-23 14:16:41.342501

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with SQLite version 3.49.1
# IPython             _testbuffer         functools           quopri
# __future__          _testcapi           gc                  random
# __hello__           _testclinic         genericpath         re
# __phello__          _testclinic_limited getopt              reprlib
# _abc                _testconsole        getpass             rlcompleter
# _aix_support        _testimportmultiple gettext             runpy
# _android_support    _testinternalcapi   glob                sched
# _apple_support      _testlimitedcapi    graphlib            secrets
# _ast                _testmultiphase     gzip                select
# _asyncio            _testsinglephase    hashlib             selectors
# _bisect             _thread             heapq               shelve
# _blake2             _threading_local    hmac                shlex
# _bz2                _tkinter            html                shutil
# _codecs             _tokenize           http                signal
# _codecs_cn          _tracemalloc        idlelib             site
# _codecs_hk          _typing             imaplib             six
# _codecs_iso2022     _uuid               importlib           smtplib
# _codecs_jp          _warnings           inspect             socket
# _codecs_kr          _weakref            io                  socketserver
# _codecs_tw          _weakrefset         ipaddress           sqlite3
# _collections        _winapi             ipykernel           sre_compile
# _collections_abc    _wmi                ipykernel_launcher  sre_constants
# _colorize           _zoneinfo           ipython_pygments_lexers sre_parse
# _compat_pickle      abc                 itertools           ssl
# _compression        antigravity         jedi                stack_data
# _contextvars        argparse            json                stat
# _csv                array               jupyter             statistics
# _ctypes             ast                 jupyter_client      string
# _ctypes_test        asttokens           jupyter_core        stringprep
# _datetime           asyncio             keyword             struct
# _decimal            atexit              linecache           subprocess
# _elementtree        base64              locale              symtable
# _functools          bdb                 logging             sys
# _hashlib            binascii            lzma                sysconfig
# _heapq              bisect              mailbox             tabnanny
# _imp                builtins            marshal             tarfile
# _interpchannels     bz2                 math                tempfile
# _interpqueues       cProfile            matplotlib_inline   test
# _interpreters       calendar            mimetypes           textwrap
# _io                 cmath               mmap                this
# _ios_support        cmd                 modulefinder        threading
# _json               code                msvcrt              time
# _locale             codecs              multiprocessing     timeit
# _lsprof             codeop              nest_asyncio2       tkinter
# _lzma               collections         netrc               token
# _markupbase         colorama            nt                  tokenize
# _md5                colorsys            ntpath              tomllib
# _multibytecodec     comm                nturl2path          tornado
# _multiprocessing    compileall          numbers             trace
# _opcode             concurrent          opcode              traceback
# _opcode_metadata    configparser        operator            tracemalloc
# _operator           contextlib          optparse            traitlets
# _osx_support        contextvars         os                  tty
# _overlapped         copy                packaging           turtle
# _pickle             copyreg             parso               turtledemo
# _py_abc             csv                 pathlib             types
# _pydatetime         ctypes              pdb                 typing
# _pydecimal          curses              pickle              typing_extensions
# _pyio               dataclasses         pickletools         unicodedata
# _pylong             datetime            pip                 unittest
# _pyrepl             dateutil            pkgutil             urllib
# _queue              dbm                 platform            uuid
# _random             debugpy             platformdirs        venv
# _sha1               decimal             plistlib            warnings
# _sha2               decorator           poplib              wave
# _sha3               difflib             posixpath           wcwidth
# _signal             dis                 pprint              weakref
# _sitebuiltins       doctest             profile             webbrowser
# _socket             email               prompt_toolkit      winreg
# _sqlite3            encodings           pstats              winsound
# _sre                ensurepip           psutil              wsgiref
# _ssl                enum                pty                 xml
# _stat               errno               pure_eval           xmlrpc
# _statistics         executing           py_compile          xxsubtype
# _string             faulthandler        pyclbr              zipapp
# _strptime           filecmp             pydoc               zipfile
# _struct             fileinput           pydoc_data          zipimport
# _suggestions        fnmatch             pyexpat             zlib
# _symtable           fractions           pygments            zmq
# _sysconfig          ftplib              queue               zoneinfo
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
