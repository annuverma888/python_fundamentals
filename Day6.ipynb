# %% [markdown]
# funtions  - block of code
# - Abstraction
# - decompostion - smaller join make larger

# %% [markdown]
# #### componesnts of a function

# %%
# parameter  - when a function creates a variable to accept a value, that variable is called a parameter.
# argument - when a function is use or  called and a value is passed to the parameter, that value is called an argument.
def fun_name (input):
    """
      docstring - write a description of the function here"""
    statement1
    return statement2
fun_name(input)

# %% [markdown]
# lets create a function (with docstring)

# %%
def is_even(num):
    """
    this function checks if no is even or not 
    input - any valid integer
    output - odd/even
    crated on =2026 -09-03"""
    if type(num) ==int:
        if num%2==0:
            return "even"
        else:
            return "odd"
    else:
        return "pagal hai kya "
#is_even(4)

# %%
for i in range(1,11):
    x = is_even(i)
    print(x)
# Out:
# odd
# even
# odd
# even
# odd
# even
# odd
# even
# odd
# even

# %%
# fetch documentation 
print(is_even.__doc__)
# Out:
# this function checks if no is even or not
# input - any valid integer
# output - odd/even
# crated on =2026 -09-03

# %%
## print ka documentation function 
print(print.__doc__)
# Out:
# Prints the values to a stream, or to sys.stdout by default.
#
#   sep
#     string inserted between values, default a space.
#   end
#     string appended after the last value, default a newline.
#   file
#     a file-like object (stream); defaults to the current sys.stdout.
#   flush
#     whether to forcibly flush the stream.

# %%
## type documentation
print(type.__doc__)
# Out:
# type(object) -> the object's type
# type(name, bases, dict, **kwds) -> a new type

# %% [markdown]
#  2 point of views

# %%
is_even("dsf")
# Out:
# 'pagal hai kya '

# %% [markdown]
# ### types of arguments
# - Default argument
# - Positional Argument
# - Keyword Argument

# %%
## def argument 
def power(a=1,b=1):
    print(a**b)
power()
power(2,3)
# Out:
# 1
# 8

# %%
#postional argument - the values passed to the function are assigned to the parameters in the order they are passed.
power(2,3) # 8 mila 9 ku ni mila 
# position follow krta pahla pahle ko milta dusara dusare ko milta order matter

# %%
# keyword argument - the values passed to the function are assigned to the parameters by their name, order does not matter.
power(a=2,b=3)
power(b=3,a=2)
# Out:
# 8
# 8

# %% [markdown]
# ## *args and **kwargs
# - are special python keywords that are used to pass the variable length of argument to a function

# %%
# *args - it allow us to pass the variable no of non-keyword arguments to a function. it is used when we are not sure how many arguments(input values) will be passed to a function.
def mul(a,b):
    return a*b
mul(2,3)
# Out:
# 6

# %%
def mul(a,b,c):
    return a*b*c
mul(2,3,4)
# Out:
# 24

# %%
def mul(*args):# args ke placepr koi bhi word use kr sakte hai
    product = 1
    for i in args:
        product = product*i
    return product
mul(1,2,3,4,45,)
mul(3,4,5,7)
# Out:
# 420

# %%
#  **kwargs - allows us to pass any no of keyword arguments 
# keyword arguments mean that contain  a key value pair like a python dictionary

# %%
def display(**kwargs): # kwargs ke place pr kuch bhi likh sakte
    for (key,value) in kwargs.items():
        print(key,"->",value)

# %%
display(india="delhi",srilanka="colambo", pakistan="islamabad",nepal="kathmandu")
# Out:
# india -> delhi
# srilanka -> colambo
# pakistan -> islamabad
# nepal -> kathmandu

# %% [markdown]
# ### points to remember while using *args and **kwargs
# - order of the arguments matter (normsl -> *args -> **kwargs)
# - the words "args" and "kwargs" are only a convention , you can use any name of your choice

# %% [markdown]
# ### how functions are executed in memory

# %%
#  you can easily see in python tutor 
 # function ek alag block hota jo memory me exist krta 
 # and lif tof function function start se return tak  uske bad destroy ho jata uske variable bhi

# %% [markdown]
# ### without return statement

# %%
## agar kisi function me return ni hai to python phir bhi return bhejta 'null'

# %%
L = [1,2,3]
print(L.append(4))
print(L)
# Out:
# None
# [1, 2, 3, 4]

# %% [markdown]
# ### variable scope

# %%
# global variable are those variable  main program ke scope ke andr aate 
# local variable are those variable function ke  scope ke andr aate

# %%
def g(y):
    print(x)
    print(x+1)
x = 5
g(x)
print(x)
# y is local variable and x is global variable
# Out:
# 5
# 6
# 5

# %%
def f(y):
    x=1
    x+=1
    print(x)
x=5
f(x)
print(x)
# Out:
# 2
# 5

# %%
def h(y):
    x+=1
x=5
h(x)
print(x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 def h(y):
#       2     x+=1
#       3 x=5
# ----> 4 h(x)
#       5 print(x)
#
# Cell In[6], line 2, in h(y)
#       1 def h(y):
# ----> 2     x+=1
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
# acha programmer istarah ke scenario ko reduce krta
def h(y):
    global x
    x+=1
x=5
h(x)
print(x)
# Out:
# 6

# %%
def f(x):
   x = x + 1
   print('in f(x): x =', x)
   return x

x = 3
z = f(x)
print('in main program scope: z =', z)
print('in main program scope: x =', x)
# Out:
# in f(x): x = 4
# in main program scope: z = 4
# in main program scope: x = 3

# %% [markdown]
# nested function

# %%
def f():
  def g():
    print('inside function g')
  g()
  print('inside function f')
f()
# Out:
# inside function g
# inside function f

# %%
# main  program se direct andr wale ko call ni kr sakte andr wala function bahar wale function ke through call hoga
def f():
  def g():
    print('inside function g')
  g()
  print('inside function f')
g()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       3   def g():
#       4     print('inside function g')
#       5   g()
#       6   print('inside function f')
# ----> 7 g()
#
# TypeError: g() missing 1 required positional argument: 'y'

# %%
def f():
  def g():
    print('inside function g')
    f()
  g()
  print('inside function f')
f()
# Out:
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# ...

# %%
def g(x):
    def h():
        x = 'abc'
    x = x + 1
    print('in g(x): x =', x)
    h()
    return x

x = 3
z = g(x)
# Out:
# in g(x): x = 4

# %%
def g(x):
    def h(x):
        x = x+1
        print("in h(x): x = ", x)
    x = x + 1
    print('in g(x): x = ', x)
    h(x)
    return x

x = 3
z = g(x)
print('in main program scope: x = ', x)
print('in main program scope: z = ', z)
# Out:
# in g(x): x =  4
# in h(x): x =  5
# in main program scope: x =  3
# in main program scope: z =  4
