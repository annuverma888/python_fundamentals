# %%
L = [1,3,4,4,55]
L.upper()  #AttributeError: 'list' object has no attribute 'upper'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 L = [1,3,4,4,55]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s ="hello"
s.append('me')  #AttributeError: 'str' object has no attribute 'append'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 s ="hello"
# ----> 2 s.append('me')
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# every thing in python is an object 
# you see inabove error

# %% [markdown]
# ### oop
# - object oriented programming
# - Generality to Specificity
# Generality to specificity in Python means starting with a broad, flexible idea and narrowing it down to a precise, detailed tool.
#
# ##  object oriented programming concepts
# - object
# - class
# - Polymorphism
# - Encapsulation
# - Inheritance
# - Abstraction

# %% [markdown]
# ### Class - class is a blueprint

# %%
L =[1,2,3,4]
print(type(L))
# Out:
# <class 'list'>

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
# python me jo bhi datatypes abhi tak padhe vo sab datatypes  class hai  aur jab bhi ham in datatypes
# ka koi variable banate ho jaise ki L=[1,2,3] to us variable ko python object banata of that class
# jaise ki L ek object hai aur list ek class hai

# %% [markdown]
# ### object - object is an instance of class

# %% [markdown]
# Syntax to create object
# <br>
# objectName = ClassName()

# %%
# object literal 
L= [1,2,3]

# %%
L = list()

# %%
s = str()

# %%
# class name - pascal case
# MyClass
# AtmClass

# %%
# class ke andr koi bhi code likh do vo execute ni hoga 
# jab tak object ni hoga

# %%
class Atm:
    
    #constructor(special function) -> superpower -> iske andr jo code likha hai usko execute  krne ke liye dont need to call constructor expicitly
    # jaise ham class ka abj banate hai automatically constructor ke andr ka code execute ho jata hai  
    def __init__(self):
        self.pin =''
        self.balance = 0
        #print('mai to execute ho gaya')
        self.menu()

    def menu(self):
        user_input = input("""
        Hi how can i help you?
        1. Press 1 to create pin
        2. press 2 to change pin 
        3. press 3 to check balance 
        4. press 4 to withdraw
        5. Anything else to exit                
        """)
    
        if user_input =='1':
            #create pin
            self.create_pin()
        elif user_input =='2':
            #change pin
            self.change_pin()
        elif user_input == '3':
            #check balance
            self.check_balance()
        elif user_input == '4':
            #withdraw
            self.withdraw()
            
        else:
            exit()
    def create_pin(self):
        user_pin = input("enter your pin")
        self.pin = user_pin
        
        user_balance = int(input('enter balance'))
        self.balance = user_balance 
        
        print('pin created successfully')
        self.menu()
    
    def change_pin(self):
        old_pin = input('enter old pin')
        
        if old_pin == self.pin:
            #let him change the pin 
            new_pin = input('enter new pin')
            self.pin = new_pin
            print('pin change successfully')
            self.menu()
        else:
            print('nahi krne de sakta re baba')
            self.menu()
    
    def check_balance(self):
        user_pin = input('enter your pin')
        if user_pin == self.pin:
            print("your balance is ", self.balance)
        else:
            print('chal nikal yaha se')
        self.menu()
    def withdraw(self):
        user_pin = input("enter the pin ")
        if user_pin == self.pin:
            #allow to withdraw 
            amount = int(input('enter the amount'))
            if amount <= self.balance:
                self.balance = self.balance -amount 
                print('withdrawl succesful balace is ',self.balance)
                
            else:
                print('abe gareeb') 
            
        else:
            print('sale chor')
        self.menu()

# %%
obj = Atm()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(type(obj))
# Out:
# <class '__main__.Atm'>

# %%
#in python classes are two types 
# user defined - atm 
# built in -list,string
