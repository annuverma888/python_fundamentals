# %% [markdown]
# python - highlevel , interpreted language and created by Guido van Rossum in 1991

# %% [markdown]
# <h3>Python output</h3>

# %%
print("Hello world")
print(2)
print(2.5)
print(True)
print('Hello',2,7.5,False)
print('Hello',2,2.75,False,sep ='/')
print("Hello")
print("Annu")
print("Hello",end='-')
print("Annu")
# Out:
# Hello world
# 2
# 2.5
# True
# Hello 2 7.5 False
# Hello/2/2.75/False
# Hello
# Annu
# Hello-Annu

# %% [markdown]
# <h3>Data type</h3>

# %%
#integer
print(8)
print(1e308)#1*10^308
print(1e309) # highest no can handle
# Out:
# 8
# 1e+308
# inf

# %%
#Decimal/float
print(8.55)
print(1.7e308)  
print(1.7e309) # highest no can handle
# Out:
# 8.55
# 1.7e+308
# inf

# %%
#boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/string
print('hello world')
# Out:
# hello world

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#list []
print([2,4,5])
# Out:
# [2, 4, 5]

# %%
# tuple
print((3,4,5))
# Out:
# (3, 4, 5)

# %%
#sets
print({1,2,3,4})
# Out:
# {1, 2, 3, 4}

# %%
# dictionary
print({'name':'Annu', 'city':'bbk', 'id':1})
# Out:
# {'name': 'Annu', 'city': 'bbk', 'id': 1}

# %% [markdown]
# <h3>type()</h3>

# %%
print(type('hello'))
print(type(7))
print(type(6.6))
print(type(4+5j))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# <h3>Variables</h3>

# %%
name="anuu"
print(name)
a=5
b=6
print(a+b)
# Out:
# anuu
# 11

# %%
# dynamic typing 
a=5  #automatically assign datatype
 
# static typing 
# int b=6   #c/c++/java 

# Dynamic binding - in python in one program one variable any type of data store 
a=5
print(a)
a="nitish"
print(a)

# static binding - ek baar data type assign kr diya uske baad data type change ni kr sakte 
# int a=5
# str a ='A'
# Out:
# 5
# nitish

# %%
a=1
b=2
c=3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=23
print(a,b,c)
# Out:
# 23 23 23

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %% [markdown]
# <h3>Comments</h3>

# %%
# python interpreter ignore this 
# not execute 
# explain the code

# %% [markdown]
# <h3>Keywords</h3>

# %%
# python are 32 keywords 
# reserved word to understand for python interpreter 

#False      None     True      and      as         assert      break       class     continue    def    del   elif   else   except  finally
#for        from     global    if       import     in          lambda       is       nonlocal    not    or    pass   raise   return     try    
#while       with     yield

# %% [markdown]
# <h3>Identifier </h3>

# %%
#  as a programmer  jab bhi aap koi name create krte like variable or function name etc. in a program 

# you can't start with a digit 
# you can use special character only 
name1 ='A'
_='A'

# %%
# identifier cannot be keyword name
name_1 ="A"
# name-1 ="A" error

# %% [markdown]
# <h3> user input </h3>  by default string isliye hota kuki string ek universal data type hai ye har type ki value store krta

# %%
input()
input("enter your name ")
# Out:
# 'Annu veeram'

# %% [markdown]
# <h3> type conversion</h3>

# %%
# Implicit 
print(5+5.6)    #automatically convert 
print(type(5),type(5.6))  
# print(4+'4')  #unsupported operand type(s) for +: 'int' and 'str'
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
# explicit
print(int('4'))
print(int(4.5))
# int(4+5j) can't convert complex to int
print(str(5))
print(float(4))
# Out:
# 4
# 4
# 5
# 4.0

# %% [markdown]
# jab bhi type conversion krte to ek naya object create krta purane value me koi change ni krta
# and type casting me original value me chanegs aa jate

# %% [markdown]
# <h3> literal </h3>   -  value ke andr jis value ko store kr rshe use literal kahte

# %%
# integer literals 

a= 0b1010  #binary literal
b=100      #decimal literal
c=0o310    #octal literal
d = 0x12c  #hexadecimal literal


# float literal 

float_1 = 10.5
float_2 = 1.5e2    # 1.5*10^2 
float_3 = 1.5e-3   #  1.5*10^-3

#complex literal  
x=3.14j  
print(x.imag ,x.real)
print(float_1,float_2,float_3)
print(a,b,c,d)


# string literal

s ='this is a python '
s = "this is a python "
char = "c"
multiline_str =""" .............................A................"""
unicode = u"\u0001f600\u0001f606"
raw_str = r"raw\n string"

print(s)
print(s)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# 3.14 0.0
# 10.5 150.0 0.0015
# 10 100 200 300
# this is a python
# this is a python
# c
#  .............................A................
# f600f606
# raw\n string

# %%
a= True+4
b=False+10
print(a,b)
# Out:
# 5 10

# %%
# None 
a = None 
print(a)
# Out:
# None

# %%
email = input("enter your email :")
password = input("enter password :")
if email == 'annu@gmail.com' and password =='1234':
     print('welcome')
elif email == 'annu@gmail.com' and password !='1234':
     print('incorrect password')
     password = input("enter correct passsword")
     if password =='1234':
         print('welcome')
     else:
         print('beta tumse na ho payega')
else:
     print('not correct')
# Out:
# not correct

# %%
#find the max of three given no

a= input("enter first no:")
b= input("enter second no:")
c= input("enter third no:")
if a>b and a>c:
    print("a is greater")
elif b>c:
    print("b is greater")
else:
    print("c is greater")
# Out:
# c is greater

# %%
# menu driven calculator 
num1 = int(input("enter first no:"))
num2 = int(input("enter second no:"))
op = input("enter the operator:")
if op=='+':
    print(num1+num2)
elif op=='-':
    print(num1+num2)
elif op=='*':
    print(num1*num2)
else:
    print(num1/num2)
# Out:
# 20

# %%
# ATM
menu = input("""
             hi ! how can i help you
             1. enter 1 for pin change
             2. enter 2. for balance check 
             3. enter 3. for withdrawl
             4.enter 4. for exit
             """)
if menu =='1':
    print("change pin")
elif menu ==2:
    print("check balance")
else:
    print("exit")
# Out:
# exit
